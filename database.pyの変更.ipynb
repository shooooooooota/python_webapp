# %%
from assets import models

# %%
import pandas as pd

from assets.database import db_session
from assets.models import Data

# %%
df = pd.read_csv('assets/data.csv')

# %%
df.head()
# Out:
#         date  subscribers  reviews
# 0  2019/1/17         2671      194
# 1  2019/1/18         2671      195
# 2  2019/1/19         2674      197
# 3  2019/1/20         2685      199
# 4  2019/1/21         2695      199

# %%
#こうすることで、0行0列目の値を持ってくることができる
df.iloc[0,0]
# Out:
# '2019/1/17'

# %%
import datetime

# %%
datetime.datetime.strptime(df.iloc[0,0], '%Y/%m/%d')
# Out:
# datetime.datetime(2019, 1, 17, 0, 0)

# %%
datetime.datetime.strptime(df.iloc[0,0], '%Y/%m/%d').date()
# Out:
# datetime.date(2019, 1, 17)

# %%
#_dfは一行ずつとってくる
for index,_df in df.iterrows():
    date= datetime.datetime.strptime(_df['date'], '%Y/%m/%d').date()
    row = models.Data(date=date, subscribers=_df['subscribers'], reviews=_df['reviews'])
    db_session.add(row)
#db_session.commit()

# %%
db_session.commit()
# Out:
# 2020-05-01 23:31:40,349 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-05-01 23:31:40,353 INFO sqlalchemy.engine.base.Engine ()
# 2020-05-01 23:31:40,354 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-05-01 23:31:40,355 INFO sqlalchemy.engine.base.Engine ()
# 2020-05-01 23:31:40,356 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-05-01 23:31:40,363 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,364 INFO sqlalchemy.engine.base.Engine ('2019-01-17', 2671, 194, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,367 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,369 INFO sqlalchemy.engine.base.Engine ('2019-01-18', 2671, 195, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,370 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,373 INFO sqlalchemy.engine.base.Engine ('2019-01-19', 2674, 197, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,375 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,376 INFO sqlalchemy.engine.base.Engine ('2019-01-20', 2685, 199, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,378 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,380 INFO sqlalchemy.engine.base.Engine ('2019-01-21', 2695, 199, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,381 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,382 INFO sqlalchemy.engine.base.Engine ('2019-01-22', 2701, 200, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,383 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,384 INFO sqlalchemy.engine.base.Engine ('2019-01-23', 2710, 200, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,387 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,388 INFO sqlalchemy.engine.base.Engine ('2019-01-24', 2718, 201, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,390 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,391 INFO sqlalchemy.engine.base.Engine ('2019-01-25', 2722, 201, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,392 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,393 INFO sqlalchemy.engine.base.Engine ('2019-01-26', 2725, 201, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,397 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,398 INFO sqlalchemy.engine.base.Engine ('2019-01-27', 2734, 202, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,400 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,402 INFO sqlalchemy.engine.base.Engine ('2019-01-28', 2753, 204, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,404 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,405 INFO sqlalchemy.engine.base.Engine ('2019-01-29', 2773, 206, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,407 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,409 INFO sqlalchemy.engine.base.Engine ('2019-01-30', 2785, 208, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,411 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,412 INFO sqlalchemy.engine.base.Engine ('2019-01-31', 2803, 210, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,413 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,414 INFO sqlalchemy.engine.base.Engine ('2019-02-01', 2845, 211, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,416 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,417 INFO sqlalchemy.engine.base.Engine ('2019-02-02', 2847, 213, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,418 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,420 INFO sqlalchemy.engine.base.Engine ('2019-02-03', 2847, 213, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,422 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,424 INFO sqlalchemy.engine.base.Engine ('2019-02-04', 2851, 217, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,425 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,426 INFO sqlalchemy.engine.base.Engine ('2019-02-05', 2852, 218, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,429 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,431 INFO sqlalchemy.engine.base.Engine ('2019-02-06', 2857, 219, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,433 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,435 INFO sqlalchemy.engine.base.Engine ('2019-02-07', 2861, 220, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,437 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,439 INFO sqlalchemy.engine.base.Engine ('2019-02-08', 2865, 222, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,441 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,442 INFO sqlalchemy.engine.base.Engine ('2019-02-09', 2870, 224, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,444 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,447 INFO sqlalchemy.engine.base.Engine ('2019-02-10', 2875, 224, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,448 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,449 INFO sqlalchemy.engine.base.Engine ('2019-02-11', 2892, 227, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,452 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,453 INFO sqlalchemy.engine.base.Engine ('2019-02-12', 2906, 229, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,455 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,457 INFO sqlalchemy.engine.base.Engine ('2019-02-13', 2919, 229, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,459 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,461 INFO sqlalchemy.engine.base.Engine ('2019-02-14', 2942, 231, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,463 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,464 INFO sqlalchemy.engine.base.Engine ('2019-02-15', 2974, 232, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,466 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,467 INFO sqlalchemy.engine.base.Engine ('2019-02-16', 2977, 234, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,468 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,469 INFO sqlalchemy.engine.base.Engine ('2019-02-17', 2978, 234, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,470 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,471 INFO sqlalchemy.engine.base.Engine ('2019-02-18', 2981, 234, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,472 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,473 INFO sqlalchemy.engine.base.Engine ('2019-02-19', 2983, 234, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,474 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,474 INFO sqlalchemy.engine.base.Engine ('2019-02-20', 2984, 237, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,475 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,477 INFO sqlalchemy.engine.base.Engine ('2019-02-21', 2987, 239, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,479 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,480 INFO sqlalchemy.engine.base.Engine ('2019-02-22', 2989, 239, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,482 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,483 INFO sqlalchemy.engine.base.Engine ('2019-02-23', 2993, 241, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,485 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,486 INFO sqlalchemy.engine.base.Engine ('2019-02-24', 2995, 241, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,487 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,487 INFO sqlalchemy.engine.base.Engine ('2019-02-25', 3009, 241, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,488 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,489 INFO sqlalchemy.engine.base.Engine ('2019-02-26', 3014, 243, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,491 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,492 INFO sqlalchemy.engine.base.Engine ('2019-02-27', 3023, 243, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,496 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,498 INFO sqlalchemy.engine.base.Engine ('2019-02-28', 3031, 243, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,501 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,502 INFO sqlalchemy.engine.base.Engine ('2019-03-01', 3052, 244, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,503 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,503 INFO sqlalchemy.engine.base.Engine ('2019-03-02', 3060, 245, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,504 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,505 INFO sqlalchemy.engine.base.Engine ('2019-03-03', 3062, 246, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,507 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,508 INFO sqlalchemy.engine.base.Engine ('2019-03-04', 3063, 249, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,509 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,511 INFO sqlalchemy.engine.base.Engine ('2019-03-05', 3066, 252, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,512 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,513 INFO sqlalchemy.engine.base.Engine ('2019-03-06', 3071, 254, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,515 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,516 INFO sqlalchemy.engine.base.Engine ('2019-03-07', 3074, 255, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,517 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,519 INFO sqlalchemy.engine.base.Engine ('2019-03-08', 3076, 256, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,520 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,524 INFO sqlalchemy.engine.base.Engine ('2019-03-09', 3077, 258, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,526 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,527 INFO sqlalchemy.engine.base.Engine ('2019-03-10', 3080, 258, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,529 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,531 INFO sqlalchemy.engine.base.Engine ('2019-03-11', 3087, 261, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,532 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,534 INFO sqlalchemy.engine.base.Engine ('2019-03-12', 3089, 261, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,535 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,537 INFO sqlalchemy.engine.base.Engine ('2019-03-13', 3093, 262, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,538 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,539 INFO sqlalchemy.engine.base.Engine ('2019-03-14', 3098, 262, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,541 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,543 INFO sqlalchemy.engine.base.Engine ('2019-03-15', 3104, 262, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,545 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,546 INFO sqlalchemy.engine.base.Engine ('2019-03-16', 3112, 262, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,548 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,550 INFO sqlalchemy.engine.base.Engine ('2019-03-17', 3120, 262, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,552 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,554 INFO sqlalchemy.engine.base.Engine ('2019-03-18', 3131, 265, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,556 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,557 INFO sqlalchemy.engine.base.Engine ('2019-03-19', 3142, 266, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,559 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,561 INFO sqlalchemy.engine.base.Engine ('2019-03-20', 3162, 266, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,563 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,565 INFO sqlalchemy.engine.base.Engine ('2019-03-21', 3173, 268, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,567 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,569 INFO sqlalchemy.engine.base.Engine ('2019-03-22', 3180, 269, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,572 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,574 INFO sqlalchemy.engine.base.Engine ('2019-03-23', 3187, 271, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,576 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,577 INFO sqlalchemy.engine.base.Engine ('2019-03-24', 3189, 271, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,579 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,581 INFO sqlalchemy.engine.base.Engine ('2019-03-25', 3196, 274, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,583 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,584 INFO sqlalchemy.engine.base.Engine ('2019-03-26', 3212, 274, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,586 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,588 INFO sqlalchemy.engine.base.Engine ('2019-03-27', 3220, 274, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,589 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,591 INFO sqlalchemy.engine.base.Engine ('2019-03-28', 3226, 275, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,593 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,595 INFO sqlalchemy.engine.base.Engine ('2019-03-29', 3241, 275, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,596 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,598 INFO sqlalchemy.engine.base.Engine ('2019-03-30', 3253, 278, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,599 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,600 INFO sqlalchemy.engine.base.Engine ('2019-03-31', 3255, 278, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,602 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,603 INFO sqlalchemy.engine.base.Engine ('2019-04-01', 3258, 280, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,605 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,607 INFO sqlalchemy.engine.base.Engine ('2019-04-02', 3262, 282, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,609 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,611 INFO sqlalchemy.engine.base.Engine ('2019-04-03', 3264, 282, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,613 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,614 INFO sqlalchemy.engine.base.Engine ('2019-04-04', 3272, 282, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,616 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,617 INFO sqlalchemy.engine.base.Engine ('2019-04-05', 3275, 284, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,619 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,620 INFO sqlalchemy.engine.base.Engine ('2019-04-06', 3276, 287, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,622 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,624 INFO sqlalchemy.engine.base.Engine ('2019-04-07', 3279, 289, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,626 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,627 INFO sqlalchemy.engine.base.Engine ('2019-04-08', 3285, 289, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,630 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,631 INFO sqlalchemy.engine.base.Engine ('2019-04-09', 3300, 291, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,632 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,633 INFO sqlalchemy.engine.base.Engine ('2019-04-10', 3306, 293, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,635 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,637 INFO sqlalchemy.engine.base.Engine ('2019-04-11', 3312, 295, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,639 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,641 INFO sqlalchemy.engine.base.Engine ('2019-04-12', 3319, 295, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,643 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,644 INFO sqlalchemy.engine.base.Engine ('2019-04-13', 3324, 295, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,646 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,648 INFO sqlalchemy.engine.base.Engine ('2019-04-14', 3325, 297, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,650 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,651 INFO sqlalchemy.engine.base.Engine ('2019-04-15', 3329, 298, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,653 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,654 INFO sqlalchemy.engine.base.Engine ('2019-04-16', 3331, 299, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,656 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,658 INFO sqlalchemy.engine.base.Engine ('2019-04-17', 3332, 299, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,660 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,661 INFO sqlalchemy.engine.base.Engine ('2019-04-18', 3333, 299, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,663 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,664 INFO sqlalchemy.engine.base.Engine ('2019-04-19', 3336, 299, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,665 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,666 INFO sqlalchemy.engine.base.Engine ('2019-04-20', 3339, 299, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,667 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,668 INFO sqlalchemy.engine.base.Engine ('2019-04-21', 3343, 300, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,671 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,673 INFO sqlalchemy.engine.base.Engine ('2019-04-22', 3349, 302, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,675 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,676 INFO sqlalchemy.engine.base.Engine ('2019-04-23', 3357, 303, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,678 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,680 INFO sqlalchemy.engine.base.Engine ('2019-04-24', 3370, 303, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,682 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,683 INFO sqlalchemy.engine.base.Engine ('2019-04-25', 3388, 304, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,685 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,687 INFO sqlalchemy.engine.base.Engine ('2019-04-26', 3412, 304, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,689 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,691 INFO sqlalchemy.engine.base.Engine ('2019-04-27', 3437, 305, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,693 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,694 INFO sqlalchemy.engine.base.Engine ('2019-04-28', 3439, 305, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,697 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,698 INFO sqlalchemy.engine.base.Engine ('2019-04-29', 3440, 308, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,699 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,701 INFO sqlalchemy.engine.base.Engine ('2019-04-30', 3447, 309, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,703 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,705 INFO sqlalchemy.engine.base.Engine ('2019-05-01', 3466, 310, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,708 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,709 INFO sqlalchemy.engine.base.Engine ('2019-05-02', 3481, 311, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,712 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,713 INFO sqlalchemy.engine.base.Engine ('2019-05-03', 3504, 314, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,716 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,717 INFO sqlalchemy.engine.base.Engine ('2019-05-04', 3522, 317, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,720 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,722 INFO sqlalchemy.engine.base.Engine ('2019-05-05', 3527, 322, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,724 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,725 INFO sqlalchemy.engine.base.Engine ('2019-05-06', 3533, 324, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,727 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,729 INFO sqlalchemy.engine.base.Engine ('2019-05-07', 3543, 327, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,731 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,732 INFO sqlalchemy.engine.base.Engine ('2019-05-08', 3546, 328, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,733 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,734 INFO sqlalchemy.engine.base.Engine ('2019-05-09', 3555, 330, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,736 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,737 INFO sqlalchemy.engine.base.Engine ('2019-05-10', 3566, 332, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,739 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,742 INFO sqlalchemy.engine.base.Engine ('2019-05-11', 3583, 334, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,743 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,745 INFO sqlalchemy.engine.base.Engine ('2019-05-12', 3594, 335, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,747 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,748 INFO sqlalchemy.engine.base.Engine ('2019-05-13', 3614, 338, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,750 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,751 INFO sqlalchemy.engine.base.Engine ('2019-05-14', 3633, 340, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,754 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,755 INFO sqlalchemy.engine.base.Engine ('2019-05-15', 3647, 344, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,757 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,758 INFO sqlalchemy.engine.base.Engine ('2019-05-16', 3648, 349, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,759 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,761 INFO sqlalchemy.engine.base.Engine ('2019-05-17', 3649, 349, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,764 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,765 INFO sqlalchemy.engine.base.Engine ('2019-05-18', 3651, 351, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,767 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,769 INFO sqlalchemy.engine.base.Engine ('2019-05-19', 3654, 351, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,770 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,772 INFO sqlalchemy.engine.base.Engine ('2019-05-20', 3658, 354, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,773 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,776 INFO sqlalchemy.engine.base.Engine ('2019-05-21', 3671, 354, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,777 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,780 INFO sqlalchemy.engine.base.Engine ('2019-05-22', 3675, 359, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,781 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,783 INFO sqlalchemy.engine.base.Engine ('2019-05-23', 3681, 359, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,785 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,786 INFO sqlalchemy.engine.base.Engine ('2019-05-24', 3694, 361, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,788 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,789 INFO sqlalchemy.engine.base.Engine ('2019-05-25', 3699, 361, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,791 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,792 INFO sqlalchemy.engine.base.Engine ('2019-05-26', 3711, 364, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,793 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,794 INFO sqlalchemy.engine.base.Engine ('2019-05-27', 3722, 368, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,797 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,799 INFO sqlalchemy.engine.base.Engine ('2019-05-28', 3734, 373, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,800 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,801 INFO sqlalchemy.engine.base.Engine ('2019-05-29', 3766, 374, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,803 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,804 INFO sqlalchemy.engine.base.Engine ('2019-05-30', 3781, 375, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,806 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,808 INFO sqlalchemy.engine.base.Engine ('2019-05-31', 3784, 375, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,810 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,812 INFO sqlalchemy.engine.base.Engine ('2019-06-01', 3789, 378, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,814 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,815 INFO sqlalchemy.engine.base.Engine ('2019-06-02', 3790, 379, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,817 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,819 INFO sqlalchemy.engine.base.Engine ('2019-06-03', 3793, 380, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,821 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,823 INFO sqlalchemy.engine.base.Engine ('2019-06-04', 3795, 383, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,824 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,826 INFO sqlalchemy.engine.base.Engine ('2019-06-05', 3808, 385, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,828 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,830 INFO sqlalchemy.engine.base.Engine ('2019-06-06', 3830, 386, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,831 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,833 INFO sqlalchemy.engine.base.Engine ('2019-06-07', 3843, 387, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,834 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,836 INFO sqlalchemy.engine.base.Engine ('2019-06-08', 3857, 390, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,838 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,840 INFO sqlalchemy.engine.base.Engine ('2019-06-09', 3870, 394, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,841 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,843 INFO sqlalchemy.engine.base.Engine ('2019-06-10', 3895, 395, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,845 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,846 INFO sqlalchemy.engine.base.Engine ('2019-06-11', 3919, 397, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,847 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,848 INFO sqlalchemy.engine.base.Engine ('2019-06-12', 3942, 399, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,849 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,852 INFO sqlalchemy.engine.base.Engine ('2019-06-13', 3983, 402, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,854 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,856 INFO sqlalchemy.engine.base.Engine ('2019-06-14', 4022, 404, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,858 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,859 INFO sqlalchemy.engine.base.Engine ('2019-06-15', 4053, 409, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,861 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,863 INFO sqlalchemy.engine.base.Engine ('2019-06-16', 4058, 410, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,865 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,866 INFO sqlalchemy.engine.base.Engine ('2019-06-17', 4063, 414, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,867 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,869 INFO sqlalchemy.engine.base.Engine ('2019-06-18', 4064, 417, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,871 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,873 INFO sqlalchemy.engine.base.Engine ('2019-06-19', 4065, 422, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,876 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,877 INFO sqlalchemy.engine.base.Engine ('2019-06-20', 4066, 424, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,879 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,881 INFO sqlalchemy.engine.base.Engine ('2019-06-21', 4069, 425, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,882 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,884 INFO sqlalchemy.engine.base.Engine ('2019-06-22', 4070, 426, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,885 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,887 INFO sqlalchemy.engine.base.Engine ('2019-06-23', 4073, 427, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,890 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,891 INFO sqlalchemy.engine.base.Engine ('2019-06-24', 4084, 427, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,893 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,894 INFO sqlalchemy.engine.base.Engine ('2019-06-25', 4108, 427, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,896 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,898 INFO sqlalchemy.engine.base.Engine ('2019-06-26', 4122, 433, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,899 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,900 INFO sqlalchemy.engine.base.Engine ('2019-06-27', 4132, 436, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,902 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,903 INFO sqlalchemy.engine.base.Engine ('2019-06-28', 4150, 440, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,904 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,906 INFO sqlalchemy.engine.base.Engine ('2019-06-29', 4162, 440, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,908 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,909 INFO sqlalchemy.engine.base.Engine ('2019-06-30', 4164, 446, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,910 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,912 INFO sqlalchemy.engine.base.Engine ('2019-07-01', 4167, 448, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,913 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,914 INFO sqlalchemy.engine.base.Engine ('2019-07-02', 4174, 450, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,915 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,919 INFO sqlalchemy.engine.base.Engine ('2019-07-03', 4179, 455, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,921 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,923 INFO sqlalchemy.engine.base.Engine ('2019-07-04', 4187, 456, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,925 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,927 INFO sqlalchemy.engine.base.Engine ('2019-07-05', 4200, 456, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,929 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,930 INFO sqlalchemy.engine.base.Engine ('2019-07-06', 4210, 458, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,933 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,934 INFO sqlalchemy.engine.base.Engine ('2019-07-07', 4211, 458, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,936 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,938 INFO sqlalchemy.engine.base.Engine ('2019-07-08', 4214, 464, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,940 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,941 INFO sqlalchemy.engine.base.Engine ('2019-07-09', 4219, 464, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,942 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,944 INFO sqlalchemy.engine.base.Engine ('2019-07-10', 4223, 468, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,946 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,948 INFO sqlalchemy.engine.base.Engine ('2019-07-11', 4228, 469, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,950 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,951 INFO sqlalchemy.engine.base.Engine ('2019-07-12', 4236, 469, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,953 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,954 INFO sqlalchemy.engine.base.Engine ('2019-07-13', 4239, 471, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,956 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,958 INFO sqlalchemy.engine.base.Engine ('2019-07-14', 4243, 471, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,960 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,961 INFO sqlalchemy.engine.base.Engine ('2019-07-15', 4250, 473, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,964 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,965 INFO sqlalchemy.engine.base.Engine ('2019-07-16', 4265, 476, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,967 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,968 INFO sqlalchemy.engine.base.Engine ('2019-07-17', 4288, 476, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,971 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,973 INFO sqlalchemy.engine.base.Engine ('2019-07-18', 4313, 483, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,975 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,976 INFO sqlalchemy.engine.base.Engine ('2019-07-19', 4329, 483, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,978 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,979 INFO sqlalchemy.engine.base.Engine ('2019-07-20', 4329, 486, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,981 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,982 INFO sqlalchemy.engine.base.Engine ('2019-07-21', 4329, 487, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,984 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,986 INFO sqlalchemy.engine.base.Engine ('2019-07-22', 4333, 492, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,987 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,989 INFO sqlalchemy.engine.base.Engine ('2019-07-23', 4335, 493, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:40,990 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:40,992 INFO sqlalchemy.engine.base.Engine ('2019-07-24', 4353, 494, '2020-05-01 23:31:28.937458')
# ...
# 2020-05-01 23:31:41,778 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,780 INFO sqlalchemy.engine.base.Engine ('2020-03-02', 6504, 878, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,782 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,783 INFO sqlalchemy.engine.base.Engine ('2020-03-03', 6510, 885, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,785 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,786 INFO sqlalchemy.engine.base.Engine ('2020-03-04', 6519, 890, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,788 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,789 INFO sqlalchemy.engine.base.Engine ('2020-03-05', 6527, 893, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,791 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,793 INFO sqlalchemy.engine.base.Engine ('2020-03-06', 6534, 894, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,795 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,797 INFO sqlalchemy.engine.base.Engine ('2020-03-07', 6539, 894, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,799 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,800 INFO sqlalchemy.engine.base.Engine ('2020-03-08', 6549, 897, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,802 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,804 INFO sqlalchemy.engine.base.Engine ('2020-03-09', 6568, 897, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,806 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,808 INFO sqlalchemy.engine.base.Engine ('2020-03-10', 6590, 902, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,810 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,812 INFO sqlalchemy.engine.base.Engine ('2020-03-11', 6609, 906, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,814 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,816 INFO sqlalchemy.engine.base.Engine ('2020-03-12', 6636, 909, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,818 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,819 INFO sqlalchemy.engine.base.Engine ('2020-03-13', 6640, 909, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,821 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,822 INFO sqlalchemy.engine.base.Engine ('2020-03-14', 6645, 911, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,824 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,825 INFO sqlalchemy.engine.base.Engine ('2020-03-15', 6649, 916, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,826 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,829 INFO sqlalchemy.engine.base.Engine ('2020-03-16', 6652, 920, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,832 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,834 INFO sqlalchemy.engine.base.Engine ('2020-03-17', 6672, 922, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,836 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,838 INFO sqlalchemy.engine.base.Engine ('2020-03-18', 6687, 926, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,840 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,841 INFO sqlalchemy.engine.base.Engine ('2020-03-19', 6707, 928, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,844 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,845 INFO sqlalchemy.engine.base.Engine ('2020-03-20', 6729, 933, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,848 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,850 INFO sqlalchemy.engine.base.Engine ('2020-03-21', 6764, 934, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,851 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,853 INFO sqlalchemy.engine.base.Engine ('2020-03-22', 6771, 939, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,855 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,856 INFO sqlalchemy.engine.base.Engine ('2020-03-23', 6776, 943, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,859 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,861 INFO sqlalchemy.engine.base.Engine ('2020-03-24', 6783, 948, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,864 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,866 INFO sqlalchemy.engine.base.Engine ('2020-03-25', 6785, 950, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,867 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,868 INFO sqlalchemy.engine.base.Engine ('2020-03-26', 6790, 951, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,869 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,870 INFO sqlalchemy.engine.base.Engine ('2020-03-27', 6792, 952, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,872 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,873 INFO sqlalchemy.engine.base.Engine ('2020-03-28', 6798, 953, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,876 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,878 INFO sqlalchemy.engine.base.Engine ('2020-03-29', 6805, 957, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,880 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,882 INFO sqlalchemy.engine.base.Engine ('2020-03-30', 6809, 958, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,883 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,884 INFO sqlalchemy.engine.base.Engine ('2020-03-31', 6832, 963, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,886 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,887 INFO sqlalchemy.engine.base.Engine ('2020-04-01', 6867, 968, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,891 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,893 INFO sqlalchemy.engine.base.Engine ('2020-04-02', 6868, 974, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,896 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,898 INFO sqlalchemy.engine.base.Engine ('2020-04-03', 6877, 977, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,900 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,901 INFO sqlalchemy.engine.base.Engine ('2020-04-04', 6882, 979, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,903 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,904 INFO sqlalchemy.engine.base.Engine ('2020-04-05', 6886, 979, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,906 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,908 INFO sqlalchemy.engine.base.Engine ('2020-04-06', 6892, 982, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,910 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,912 INFO sqlalchemy.engine.base.Engine ('2020-04-07', 6912, 987, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,915 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,917 INFO sqlalchemy.engine.base.Engine ('2020-04-08', 6913, 991, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,918 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,920 INFO sqlalchemy.engine.base.Engine ('2020-04-09', 6921, 993, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,921 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,923 INFO sqlalchemy.engine.base.Engine ('2020-04-10', 6927, 995, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,925 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,926 INFO sqlalchemy.engine.base.Engine ('2020-04-11', 6938, 996, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,927 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,928 INFO sqlalchemy.engine.base.Engine ('2020-04-12', 6941, 998, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,931 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,931 INFO sqlalchemy.engine.base.Engine ('2020-04-12', 6941, 998, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,933 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,934 INFO sqlalchemy.engine.base.Engine ('2020-04-12', 6941, 998, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,935 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,936 INFO sqlalchemy.engine.base.Engine ('2020-04-12', 6941, 998, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,937 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,938 INFO sqlalchemy.engine.base.Engine ('2020-04-12', 6941, 998, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,942 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,945 INFO sqlalchemy.engine.base.Engine ('2020-04-13', 6948, 1002, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,947 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,948 INFO sqlalchemy.engine.base.Engine ('2020-04-14', 6956, 1006, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,949 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,950 INFO sqlalchemy.engine.base.Engine ('2020-04-15', 6982, 1007, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,951 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,952 INFO sqlalchemy.engine.base.Engine ('2020-04-16', 7003, 1007, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,954 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,955 INFO sqlalchemy.engine.base.Engine ('2020-04-17', 7024, 1012, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,957 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,959 INFO sqlalchemy.engine.base.Engine ('2020-04-18', 7050, 1016, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,960 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,961 INFO sqlalchemy.engine.base.Engine ('2020-04-19', 7092, 1017, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,964 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,965 INFO sqlalchemy.engine.base.Engine ('2020-04-20', 7154, 1021, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,966 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,967 INFO sqlalchemy.engine.base.Engine ('2020-04-21', 7233, 1028, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,969 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,971 INFO sqlalchemy.engine.base.Engine ('2020-04-22', 7245, 1031, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,974 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,976 INFO sqlalchemy.engine.base.Engine ('2020-04-23', 7257, 1033, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,978 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,979 INFO sqlalchemy.engine.base.Engine ('2020-04-24', 7265, 1045, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,981 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,982 INFO sqlalchemy.engine.base.Engine ('2020-04-25', 7269, 1048, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,983 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,985 INFO sqlalchemy.engine.base.Engine ('2020-04-26', 7276, 1053, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,987 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,988 INFO sqlalchemy.engine.base.Engine ('2020-04-27', 7281, 1055, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,990 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,991 INFO sqlalchemy.engine.base.Engine ('2020-04-28', 7290, 1059, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:41,993 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-05-01 23:31:41,994 INFO sqlalchemy.engine.base.Engine ('2020-04-29', 7328, 1064, '2020-05-01 23:31:28.937458')
# 2020-05-01 23:31:42,005 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
def read_data():
    from .assets import models
    df = pd.read_csv('assets/data.csv')

    #_dfは一行ずつとってくる
    for index,_df in df.iterrows():
    # date型への変更
        date= datetime.datetime.strptime(_df['date'], '%Y/%m/%d').date()
        row = models.Data(date=date, subscribers=_df['subscribers'], reviews=_df['reviews'])
        db_session.add(row)
    db_session.commit()
